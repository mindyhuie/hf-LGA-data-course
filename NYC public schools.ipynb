# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#load dataset from url
df=pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')

# %%
#explore data

# %%
df
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 0               Common Core Algebra  2017             4          s
# 1                Living Environment  2015            16       77.9
# ...

# %%
#looking for information

# %%
df.head()
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
#
#           Regents Exam  Year  Total Tested Mean Score Number Scoring Below 65  \
# 0  Common Core Algebra  2017             4          s                       s
# 1   Living Environment  2015            16       77.9                       1
# 2   Living Environment  2016             9         74                       1
# 3  Common Core Algebra  2016             3          s                       s
# 4  Common Core Algebra  2017             2          s                       s
#
#   Percent Scoring Below 65 Number Scoring 65 or Above  \
# 0                        s                          s
# ...

# %%
#looking at columns to check the names

# %%
df.columns
# Out:
# Index(['School DBN', 'School Name', 'School Level', 'Regents Exam', 'Year',
#        'Total Tested', 'Mean Score', 'Number Scoring Below 65',
#        'Percent Scoring Below 65', 'Number Scoring 65 or Above',
#        'Percent Scoring 65 or Above', 'Number Scoring 80 or Above',
#        'Percent Scoring 80 or Above', 'Number Scoring CR',
#        'Percent Scoring CR'],
#       dtype='object')

# %%
#filter to specifically common core algebra

# %%
df1=df[df['Regents Exam']=='Common Core Algebra']

# %%
df1
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# 8          01M184            P.S. 184m Shuang Wen          K-8
# 9          01M184            P.S. 184m Shuang Wen          K-8
# ...           ...                             ...          ...
# 212319     84X717            Icahn Charter School          K-8
# 212320     84X717            Icahn Charter School          K-8
# 212321     84X717            Icahn Charter School          K-8
# 212322     84X717            Icahn Charter School          K-8
# 212323     84X717            Icahn Charter School          K-8
#
#                Regents Exam  Year  Total Tested Mean Score  \
# 0       Common Core Algebra  2017             4          s
# 3       Common Core Algebra  2016             3          s
# ...

# %%
#delete columns  specifically number scoring CR and percent scoring cr

# %%
drop_cols=['Number Scoring CR','Percent Scoring CR']

# %%
df1.drop(drop_cols,inplace=True, axis=1)
# Out:
# C:\Users\Tifa\AppData\Local\Temp\ipykernel_9864\2655887927.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop(drop_cols,inplace=True, axis=1)

# %%
df1
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# 8          01M184            P.S. 184m Shuang Wen          K-8
# 9          01M184            P.S. 184m Shuang Wen          K-8
# ...           ...                             ...          ...
# 212319     84X717            Icahn Charter School          K-8
# 212320     84X717            Icahn Charter School          K-8
# 212321     84X717            Icahn Charter School          K-8
# 212322     84X717            Icahn Charter School          K-8
# 212323     84X717            Icahn Charter School          K-8
#
#                Regents Exam  Year  Total Tested Mean Score  \
# 0       Common Core Algebra  2017             4          s
# 3       Common Core Algebra  2016             3          s
# ...

# %%
df1.describe()
# Out:
#                Year  Total Tested
# count  29254.000000  29254.000000
# mean    2016.040952     53.607199
# std        0.814378     91.826721
# min     2015.000000      1.000000
# 25%     2015.000000      5.000000
# 50%     2016.000000     22.000000
# 75%     2017.000000     67.000000
# max     2017.000000   1384.000000

# %%
#change column name from regents exam to exam regents

# %%
df1.rename(columns={'Regents Exam':'Exam Regent'}, inplace=True)
# Out:
# C:\Users\Tifa\AppData\Local\Temp\ipykernel_9864\2138266244.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.rename(columns={'Regents Exam':'Exam Regent'}, inplace=True)

# %%
df1
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# 8          01M184            P.S. 184m Shuang Wen          K-8
# 9          01M184            P.S. 184m Shuang Wen          K-8
# ...           ...                             ...          ...
# 212319     84X717            Icahn Charter School          K-8
# 212320     84X717            Icahn Charter School          K-8
# 212321     84X717            Icahn Charter School          K-8
# 212322     84X717            Icahn Charter School          K-8
# 212323     84X717            Icahn Charter School          K-8
#
#                 Exam Regent  Year  Total Tested Mean Score  \
# 0       Common Core Algebra  2017             4          s
# 3       Common Core Algebra  2016             3          s
# ...

# %%
#filter to specific school to do the compare

# %%
df2=df1[df1['School Name']=='Abraham Lincoln High School']

# %%
df2
# Out:
#        School DBN                  School Name School Level  \
# 12518      21K410  Abraham Lincoln High School  High school
# 12519      21K410  Abraham Lincoln High School  High school
# 12520      21K410  Abraham Lincoln High School  High school
# 41903      21K410  Abraham Lincoln High School  High school
# 41904      21K410  Abraham Lincoln High School  High school
# 41905      21K410  Abraham Lincoln High School  High school
# 41906      21K410  Abraham Lincoln High School  High school
# 41907      21K410  Abraham Lincoln High School  High school
# 41908      21K410  Abraham Lincoln High School  High school
# 85844      21K410  Abraham Lincoln High School  High school
# 85845      21K410  Abraham Lincoln High School  High school
# 85846      21K410  Abraham Lincoln High School  High school
# 85847      21K410  Abraham Lincoln High School  High school
# 85848      21K410  Abraham Lincoln High School  High school
# 85849      21K410  Abraham Lincoln High School  High school
# ...

# %%
df2.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Year'}>,
#         <AxesSubplot:title={'center':'Total Tested'}>]], dtype=object)

# %%
# mean  median for specific school Abraham high school

# %%
df2['Total Tested'].mean()
# Out:
# 311.53846153846155

# %%
df2['Total Tested'].median()
# Out:
# 225.0

# %%
# make comparision to specific high school

# %%
df3=df1[df1['School Name']=='P.S. 184m Shuang Wen']

# %%
df3
# Out:
#        School DBN           School Name School Level          Exam Regent  \
# 8          01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 9          01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 10         01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 19489      01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 19490      01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 19491      01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 19492      01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 19493      01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 19494      01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 54250      01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 54251      01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 54252      01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# ...

# %%
#need to clean out the filter  data  remove S

# %%
df4=df3[df3['Percent Scoring 80 or Above']!='s']

# %%
df4
# Out:
#        School DBN           School Name School Level          Exam Regent  \
# 8          01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 9          01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 10         01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 54251      01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 54254      01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 54257      01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 102895     01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 102896     01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 102897     01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 102898     01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 102899     01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 102900     01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# ...

# %%
df4.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Year'}>,
#         <AxesSubplot:title={'center':'Total Tested'}>]], dtype=object)

# %%
# mean  median for specific school Shuang Wen

# %%
df4['Total Tested'].mean()
# Out:
# 35.46666666666667

# %%
df4['Total Tested'].median()
# Out:
# 36.0

# %%
# plot  both two charts comparing both high school with higher than 80

# %%
df4.plot(kind='line', x='Percent Scoring 80 or Above', y= 'Year')
# Out:
# <AxesSubplot:xlabel='Percent Scoring 80 or Above'>

# %%
df2.plot(kind='line', x='Percent Scoring 80 or Above', y= 'Year')
# Out:
# <AxesSubplot:xlabel='Percent Scoring 80 or Above'>

# %%
#base off analysis  Abraham high school have more people taking the test for algebra than Shuang Wen high school. 311 people tested in abraham high school compare to Shuang wen high school only has 35 people totally tested
